# %% [markdown]
# # Programação
#
# ## 1º Teste
#
# ### 06/12/2023

# %% [markdown]
# Nome:
# Nº:

# %% [markdown]
# 1.(1 Valor) - Fazer um programa que imprima:
#
# O meu nome é (primeiro nome) (último nome).
#
# O meu número de estudante é ....

# %% [markdown]
# 2.(2 Valores) - Explique por palavras suas o que é um algoritmo.

# %% [markdown]
# 3.(1 Valor) - Como escrever um comentário em Python no meio do código?

# %% [markdown]
# 4.(1 Valores) Fazer programa que pergunte "Qual a sua idade?" e depois imprima "A sua idade é (a idade respondida)"

# %% [markdown]
# 5.(3 Valores) - Fazer um programa que peça 3 números e que depois imprima o maior número e o menor número.

# %% [markdown]
# 6.(2 Valores) - Faça um programa para escrever a contagem regressiva do lançamento de um foguetão. O
# programa deve imprimir os números de 10 até 0 e depois imprimir "Lançamento!"(usar while).

# %% [markdown]
# 7.(2 Valores) - Considere a seguinte imagem:
#
# ![image.png](attachment:aa9f87e1-daf4-4219-8481-3b8a15ff5b07.png)
#
# Faça um programa que consoante os valores de b e c, calcule o valor da hipotenusa (a) do triângulo retângulo.

# %% [markdown]
# 8.(4 Valores) - Escreva um programa que pergunte qual a forma geométrica.
#
# Quadrado - 1;
# Retângulo - 2;
# Círculo - 3;
#
# Consoante opção escolhida pergunta os dados necessários para calcular o perímetro e a área a área da forma geométrica escolhida.
#
# Imprime o perímetro e a área da forma escolhida.
#
# Termine com "obrigado"

# %% [markdown]
# 9.(4 Valores) - Faça um programa que pergunte as alturas dos 11 jogadores titulares de uma equipa de futebol e que calcule a altura média dos jogadores.
#
# (O programa deverá utilizar o ciclo while)
#
# O programa deve terminar com a impressão de (Obrigado)
#
# Na tela deve aparecer a seguinte informação:
#
# jogador 1
#
# (input)Altura do jogador (xxx - informação que vai ser colocada...)
#
# O jogador 1 tem a altura XXXX
#
# jogador 2
#
# (input)Altura do jogador (aaa - informação que vai ser colocada...)
#
# O jogador 2 tem a altura aaa
#
# ...
#
# (Até ao 11º jogador.)
#
# A altura média dos jogadores é (yyy)
#
# Obrigado
